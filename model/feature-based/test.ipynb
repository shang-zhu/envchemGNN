# %%
import pandas as pd

# %%
data_path='/ocean/projects/cts180021p/shang9/molecules/pretrainLCA/finalized/data/'
input_path=data_path+'model_input/random_split/BCF.csv' 
output_path=data_path+'features/BCF/'

label_csv=input_path
feat_dir=output_path

# %%
#creating results folder
if not os.path.exists(feat_dir):
    os.makedirs(feat_dir)
    
#'grover' 'dvmp' features are left for a future study
for feat_type in ['mordred']:
    smi2feat(label_csv, feat_dir, feat_type=feat_type)
# Out:
#   1%|          | 6/1056 [00:10<24:38,  1.41s/it]Exception in thread Thread-3:
# Traceback (most recent call last):
#   File "/ocean/projects/civ210001p/shang9/miniconda3/envs/ml_env/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/ocean/projects/civ210001p/shang9/miniconda3/envs/ml_env/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/ocean/projects/civ210001p/shang9/miniconda3/envs/ml_env/lib/python3.6/multiprocessing/pool.py", line 405, in _handle_workers
#     pool._maintain_pool()
#   File "/ocean/projects/civ210001p/shang9/miniconda3/envs/ml_env/lib/python3.6/multiprocessing/pool.py", line 246, in _maintain_pool
#     self._repopulate_pool()
#   File "/ocean/projects/civ210001p/shang9/miniconda3/envs/ml_env/lib/python3.6/multiprocessing/pool.py", line 239, in _repopulate_pool
#     w.start()
# ...
